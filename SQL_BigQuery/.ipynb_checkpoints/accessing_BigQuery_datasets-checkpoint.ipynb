# %% [markdown]
# # Basics of accessing and examing BigQuery datasets

# %%
# import package
from google.cloud import bigquery
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cae9206c4b4e> in <module>
#       1 # import package
# ----> 2 from google.cloud import bigquery
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/__init__.py in <module>
#      33 __version__ = bigquery_version.__version__
#      34
# ---> 35 from google.cloud.bigquery.client import Client
#      36 from google.cloud.bigquery.dataset import AccessEntry
#      37 from google.cloud.bigquery.dataset import Dataset
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in <module>
#      54 from google.cloud.bigquery._helpers import _verify_job_config_type
#      55 from google.cloud.bigquery._http import Connection
# ---> 56 from google.cloud.bigquery import _pandas_helpers
#      57 from google.cloud.bigquery.dataset import Dataset
#      58 from google.cloud.bigquery.dataset import DatasetListItem
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/_pandas_helpers.py in <module>
#      34     pyarrow = None
#      35
# ---> 36 from google.cloud.bigquery import schema
#      37
#      38
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/schema.py in <module>
#      17 import collections
#      18
# ---> 19 from google.cloud.bigquery_v2 import types
#      20
#      21
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery_v2/__init__.py in <module>
#      18
#      19 from .types.encryption_config import EncryptionConfiguration
# ---> 20 from .types.model import DeleteModelRequest
#      21 from .types.model import GetModelRequest
#      22 from .types.model import ListModelsRequest
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery_v2/types/__init__.py in <module>
#      17
#      18 from .encryption_config import EncryptionConfiguration
# ---> 19 from .model import (
#      20     DeleteModelRequest,
#      21     GetModelRequest,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery_v2/types/model.py in <module>
#      21 from google.cloud.bigquery_v2.types import encryption_config
#      22 from google.cloud.bigquery_v2.types import model_reference as gcb_model_reference
# ---> 23 from google.cloud.bigquery_v2.types import standard_sql
#      24 from google.cloud.bigquery_v2.types import table_reference
#      25 from google.protobuf import timestamp_pb2 as timestamp  # type: ignore
#
# ~/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery_v2/types/standard_sql.py in <module>
#      94
#      95
# ---> 96 class StandardSqlStructType(proto.Message):
#      97     r"""
#      98
#
# ~/opt/anaconda3/lib/python3.7/site-packages/proto/message.py in __new__(mcls, name, bases, attrs)
#     261         # Generate the descriptor for the file if it is ready.
#     262         if file_info.ready(new_class=cls):
# --> 263             file_info.generate_file_pb(new_class=cls, fallback_salt=full_name)
#     264
#     265         # Done; return the class.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/proto/_file_info.py in generate_file_pb(self, new_class, fallback_salt)
#     100
#     101         # Add the file descriptor.
# --> 102         pool.Add(self.descriptor)
#     103
#     104         # Adding the file descriptor to the pool created a descriptor for
#
# TypeError: Couldn't build proto file into descriptor pool!
# Invalid proto descriptor for file "google/cloud/bigquery_v2/types/standard_sql.proto":
#   google.cloud.bigquery.v2.StandardSqlDataType.sub_type: "sub_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: "type_kind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.array_element_type: "array_element_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.struct_type: "struct_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: "TYPE_KIND_UNSPECIFIED" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TYPE_KIND_UNSPECIFIED" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: "INT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "INT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: "BOOL" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BOOL" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: "FLOAT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "FLOAT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: "STRING" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRING" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: "BYTES" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BYTES" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: "DATE" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATE" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: "ARRAY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "ARRAY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: "STRUCT" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRUCT" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: "TIMESTAMP" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIMESTAMP" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: "TIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: "DATETIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATETIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: "GEOGRAPHY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "GEOGRAPHY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: "NUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "NUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: "BIGNUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BIGNUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TypeKind: "TypeKind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType: "StandardSqlDataType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlField.name: "name" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField.type: "type" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField: "StandardSqlField" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlStructType.fields: "fields" is already defined in "google.cloud.bigquery.v2.StandardSqlStructType".
#   google.cloud.bigquery.v2.StandardSqlStructType: "StandardSqlStructType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlDataType.sub_type: "sub_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: "type_kind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.array_element_type: "array_element_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.struct_type: "struct_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: "TYPE_KIND_UNSPECIFIED" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TYPE_KIND_UNSPECIFIED" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: "INT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "INT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: "BOOL" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BOOL" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: "FLOAT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "FLOAT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: "STRING" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRING" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: "BYTES" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BYTES" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: "DATE" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATE" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: "ARRAY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "ARRAY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: "STRUCT" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRUCT" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: "TIMESTAMP" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIMESTAMP" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: "TIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: "DATETIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATETIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: "GEOGRAPHY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "GEOGRAPHY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: "NUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "NUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: "BIGNUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BIGNUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TypeKind: "TypeKind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType: "StandardSqlDataType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlField.name: "name" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField.type: "type" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField: "StandardSqlField" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlStructType.fields: "fields" is already defined in "google.cloud.bigquery.v2.StandardSqlStructType".
#   google.cloud.bigquery.v2.StandardSqlStructType: "StandardSqlStructType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlDataType.sub_type: "sub_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: "type_kind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.array_element_type: "array_element_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.struct_type: "struct_type" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: "TYPE_KIND_UNSPECIFIED" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TYPE_KIND_UNSPECIFIED: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TYPE_KIND_UNSPECIFIED" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: "INT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.INT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "INT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: "BOOL" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BOOL: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BOOL" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: "FLOAT64" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.FLOAT64: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "FLOAT64" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: "STRING" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRING: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRING" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: "BYTES" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BYTES: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BYTES" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: "DATE" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATE: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATE" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: "ARRAY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.ARRAY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "ARRAY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: "STRUCT" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.STRUCT: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "STRUCT" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: "TIMESTAMP" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIMESTAMP: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIMESTAMP" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: "TIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.TIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "TIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: "DATETIME" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.DATETIME: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "DATETIME" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: "GEOGRAPHY" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.GEOGRAPHY: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "GEOGRAPHY" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: "NUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.NUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "NUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: "BIGNUMERIC" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType.BIGNUMERIC: Note that enum values use C++ scoping rules, meaning that enum values are siblings of their type, not children of it.  Therefore, "BIGNUMERIC" must be unique within "google.cloud.bigquery.v2.StandardSqlDataType", not just within "TypeKind".
#   google.cloud.bigquery.v2.StandardSqlDataType.TypeKind: "TypeKind" is already defined in "google.cloud.bigquery.v2.StandardSqlDataType".
#   google.cloud.bigquery.v2.StandardSqlDataType: "StandardSqlDataType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlField.name: "name" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField.type: "type" is already defined in "google.cloud.bigquery.v2.StandardSqlField".
#   google.cloud.bigquery.v2.StandardSqlField: "StandardSqlField" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlStructType.fields: "fields" is already defined in "google.cloud.bigquery.v2.StandardSqlStructType".
#   google.cloud.bigquery.v2.StandardSqlStructType: "StandardSqlStructType" is already defined in "google.cloud.bigquery.v2".
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: Field with primitive type has type_name.
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: Field with primitive type has type_name.
#   google.cloud.bigquery.v2.StandardSqlDataType.type_kind: Field with primitive type has type_name.

# %% [markdown]
# ## 1. Create Client Object
#
# The client object plays a central role in retrieving information from BigQuery datasets.

# %%
# create a client object
client = bigquery.Client()

# %% [markdown]
# ## 2. Access the Dataset in BigQuery
#
# In BigQuery, each dataset is contained in a corresponding project. I'll access the project called "bigquery-public-data" and obtain the dataset, "hacker_new" which is a dataset of posts on [Hacker News](https://news.ycombinator.com/), a website focusing on computer science and cybersecurity news.
#
# - <code>dataset()</code> for constructing a reference to dataset
# - <code>get_dataset()</code> for fetching the dataset (by including the reference inside the parentheses)

# %%
# construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("hacker_news", project = "bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# <br>
# The dataset comprises of multiple tables composed of rows and columns.<br>
# <code>list_tables()</code> for listing the tables in the dataset.

# %%
# list all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# print names of all tables in the dataset
for table in tables:
    print(table.table_id)

# %% [markdown]
# <br>
# As the output above says, the dataset, "hacker_news" is a collection of <font color="green"><b> four tables: comments, full, full_201510, stories.</b> </font>

# %% [markdown]
# <br>
# Now, I'll fetch one table by constructing a reference to the table name and using <code>get_table()</code> method.

# %%
# construct a reference to the "full" table
table_ref = dataset_ref.table("full")

# API request - fetch the table
table = client.get_table(table_ref)

# %% [markdown]
# ## Summary
#
# - **Client** holds Projects & Connection.
# - **Project** holds a collection of datasets.
# - **Dataset** holds a collection of tables.
# <br>
#
# !['BigQuery Overview'](https://i.imgur.com/biYqbUB.png)
# [image source: Kaggle]

# %% [markdown]
# ## 3. Checking Table Schema
#
# Table Schema means the structure of a table. To effectively pull out the data, I'll check the table schema of the <code>full</code> table.

# %%
# first, print information on all the columns in the "full" table in the "hacker_news" dataset
table.schema

# %% [markdown]
# **SchemaField** tells us about column(also often called "field") information.
# In order, the information is:
#
# - the name of the column
# - the field type (or datatype) in the column
# - the mode of the column ('NULLABLE' means that a column allows NULL values and is the default)
# - a description of the data in that column
#
# The first field has the SchemaField:
#
# <code>SchemaField('title', 'STRING', 'NULLABLE', 'Story title', (), None)</code>
#
# This tells us:
#
# - the field(column) name: <code>title</code>
# - the datatype: <code>string</code>
# - the mode: NULL value are allowed.
# - the description: Story title
#
# Now, using <code>list_rows()</code>, let's check the first five rows of the <code>full</code> table in the <code>hacker_news</code> dataset.

# %%
# preview the first five rows of the "full" table
client.list_rows(table, max_results=5).to_dataframe()
